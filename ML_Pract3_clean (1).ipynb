# %%
import numpy as np
import matplotlib .pyplot as plt
import seaborn as sns
df = pd.read_csv ("bank.csv" )
df1
8/9/23, 10:04 PM pract_3 - Jupyter Notebook

# %%
20]:Out[17]:
RowNumber            int64
CustomerId           int64
Surname             object
CreditScore          int64
Geography           object
Gender              object
Age                  int64
Tenure               int64
Balance            float64
NumOfProducts        int64
HasCrCard            int64
IsActiveMember       int64
EstimatedSalary    float64
Exited               int64
dtype: object
Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
      'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
      'IsActiveMember', 'EstimatedSalary', 'Exited'],
     dtype='object')
CreditScore Geography Gender Age T enure Balance NumOfProducts HasCrCard Is
0 619 France Female 42 2 0.00 1 1
1 608 Spain Female 41 1 83807.86 1 0
2 502 France Female 42 8159660.80 3 1
3 699 France Female 39 1 0.00 2 0
4 850 Spain Female 43 2125510.82 1 1df.dtypes
df.columns
df = df.drop(['RowNumber' ,'CustomerId' ,'Surname' ], axis = 1)
df.head()1
8/9/23, 10:04 PM pract_3 - Jupyter Notebook

# %%
24]:
def visualization  (x,y,xlabel):
    plt.figure(figsize=(10,5))
    plt.hist([x,y], color=['red','green'], label=['exit', 'not_exit' ])
    plt.xlabel(xlabel,fontsize =20)
    plt.ylabel("No. of customers" , fontsize  = 20)
    plt.legend()
df_churn_exited  = df [df['Exited' ]==1]['Tenure' ]
df_churn_not_exited  = df[df['Exited' ]==0]['Tenure' ]
visualization (df_churn_exited ,df_churn_not_exited ,"Tenure" )
df_churn_exited  = df [df['Exited' ]==1]['Age']
df_churn_not_exited  = df[df['Exited' ]==0]['Age']1
8/9/23, 10:04 PM pract_3 - Jupyter Notebook

# %%
28]:
CreditScore          int64
Geography           object
Gender              object
Age                  int64
Tenure               int64
Balance            float64
NumOfProducts        int64
HasCrCard            int64
IsActiveMember       int64
EstimatedSalary    float64
Exited               int64
dtype: objectvisualization (df_churn_exited ,df_churn_not_exited ,"Age")
df.dtypes
x = df[['CreditScore' ,'Gender' ,'Age','Tenure' ,'Balance' , 'NumOfProducts' ,'HasCrCard'
states = pd.get_dummies (df['Geography' ],drop_first = True)
gender = pd.get_dummies (df['Gender' ],drop_first = True)
df = pd.concat([df,gender,states], axis=1)1
8/9/23, 10:04 PM pract_3 - Jupyter Notebook

# %%
34]:Out[29]:
CreditScore Geography Gender Age T enure Balance NumOfProducts HasCrCard Is
0 619 France Female 42 2 0.00 1 1
1 608 Spain Female 41 1 83807.86 1 0
2 502 France Female 42 8159660.80 3 1
3 699 France Female 39 1 0.00 2 0
4 850 Spain Female 43 2125510.82 1 1
(10000, 9)
(2500, 9)df.head()
x = df[['CreditScore' ,'Age','Tenure' ,'Balance' , 'NumOfProducts' ,'HasCrCard' ,'IsActiv
y = df['Exited' ]
from sklearn.model_selection  import train_test_split
x_train,x_test,y_train,y_test = train_test_split (x,y,random_state =0, test_size =0.25)
x.shape
x_test.shape1
8/9/23, 10:04 PM pract_3 - Jupyter Notebook

# %%
40]:Out[43]:
array([[-1.13575957, -0.46944165, -0.70387817, ..., -1.02664045,
        0.60325767, -0.50290013],
      [-0.42644403,  1.73021217,  0.67859859, ...,  0.97405085,
        0.2269567 ,  1.98846639],
      [ 1.29030518,  0.39129245, -1.39511655, ..., -1.02664045,
       -1.36445846, -0.50290013],
      ...,
      [ 2.04074047,  0.5825667 , -0.01263979, ...,  0.97405085,
        1.61079312,  1.98846639],
      [-0.87876119, -0.2781674 , -1.39511655, ..., -1.02664045,
       -0.35801334, -0.50290013],
      [-0.38532429,  0.20001821, -0.70387817, ...,  0.97405085,
        1.37555676, -0.50290013]])
(2500, 9)
(7500, 9)
C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\_multila
yer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum i
terations (100) reached and the optimization hasn't converged yet.
 warnings.warn(
MLPClassifier(hidden_layer_sizes=(100, 100, 100), max_iter=100, random_sta
te=0)x_train
x_test.shape
x_train.shape
from sklearn.neural_network  import MLPClassifier
ann = MLPClassifier (hidden_layer_sizes =(100,100,100),
                   random_state  =0,
                   max_iter =100, activation ='relu')
ann.fit(x_train,y_train)1
8/9/23, 10:04 PM pract_3 - Jupyter Notebook

# %%
49]:Out[42]:
array([0, 0, 0, ..., 0, 0, 0], dtype=int64)
0    1991
1     509
Name: Exited, dtype: int64y_pred =ann.predict(x_test)
y_pred
import sklearn
from sklearn.metrics import ConfusionMatrixDisplay , classification_report
from sklearn.metrics import accuracy_score
y_test.value_counts ()1
8/9/23, 10:04 PM pract_3 - Jupyter Notebook

# %%
52]:Out[50]:
<sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay at 0x2257a6
4b3d0>
0.7956
             precision    recall  f1-score   support
          0       0.80      1.00      0.89      1991
          1       0.33      0.00      0.01       509
   accuracy                           0.80      2500
  macro avg       0.57      0.50      0.45      2500
weighted avg       0.70      0.80      0.71      2500ConfusionMatrixDisplay .from_predictions (y_test,y_pred)
accuracy_score (y_test,y_pred)
print(classification_report (y_test,y_pred))1
8/9/23, 10:04 PM pract_3 - Jupyter Notebook
